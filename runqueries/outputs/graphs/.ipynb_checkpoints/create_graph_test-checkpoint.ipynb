# %%
# Importar bibliotecas necesarias
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Leer datos desde el archivo CSV
# type fun 0
dataPartialLoudsBackf0 = pd.read_csv('../partial/louds/backtracking/results-f0.csv', delimiter=';')
dataPartialLoudsNonFixedf0 = pd.read_csv('../partial/louds/nonFixedQueue/results-f0.csv', delimiter=';')
dataPartialDfudsBackf0 = pd.read_csv('../partial/dfuds/backtracking/results-f0.csv', delimiter=';')
dataPartialDfudsNonFixedf0 = pd.read_csv('../partial/dfuds/nonFixedQueue/results-f0.csv', delimiter=';')
dataRankedLoudsBackf0 = pd.read_csv('../ranked/louds/backtracking/results-f0.csv', delimiter=';')
dataRankedLoudsNonFixedf0 = pd.read_csv('../ranked/louds/nonFixedQueue/results-f0.csv', delimiter=';')
dataRankedDfudsBackf0 = pd.read_csv('../ranked/dfuds/backtracking/results-f0.csv', delimiter=';')
dataRankedDfudsNonFixedf0 = pd.read_csv('../ranked/dfuds/nonFixedQueue/results-f0.csv', delimiter=';')

# type fun 1
dataPartialLoudsBackf1 = pd.read_csv('../partial/louds/backtracking/results-f1.csv', delimiter=';')
dataPartialLoudsNonFixedf1 = pd.read_csv('../partial/louds/nonFixedQueue/results-f1.csv', delimiter=';')
dataPartialDfudsBackf1 = pd.read_csv('../partial/dfuds/backtracking/results-f1.csv', delimiter=';')
dataPartialDfudsNonFixedf1 = pd.read_csv('../partial/dfuds/nonFixedQueue/results-f1.csv', delimiter=';')
dataRankedLoudsBackf1 = pd.read_csv('../ranked/louds/backtracking/results-f1.csv', delimiter=';')
dataRankedLoudsNonFixedf1 = pd.read_csv('../ranked/louds/nonFixedQueue/results-f1.csv', delimiter=';')
dataRankedDfudsBackf1 = pd.read_csv('../ranked/dfuds/backtracking/results-f1.csv', delimiter=';')
dataRankedDfudsNonFixedf1 = pd.read_csv('../ranked/dfuds/nonFixedQueue/results-f1.csv', delimiter=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [109], in <cell line: 3>()
#       1 # Leer datos desde el archivo CSV
#       2 # type fun 0
# ----> 3 dataPartialLoudsBackf0 = pd.read_csv('../partial/louds/backtracking/results-f0.csv', delimiter=';')
#       4 dataPartialLoudsNonFixedf0 = pd.read_csv('../partial/louds/nonFixedQueue/results-f0.csv', delimiter=';')
#       5 dataPartialDfudsBackf0 = pd.read_csv('../partial/dfuds/backtracking/results-f0.csv', delimiter=';')
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
# ...

# %%
# Variables del archivo
variables = dataPartialLoudsBackf0.columns[1:]  # Excluir la columna 'k'
variables
# Out:
# Index(['j3', 'j4', 'p2', 'p3', 'p4', 's1', 's2', 's3', 's4', 't2', 't3', 't4',
#        'ti2', 'ti3', 'ti4', 'tr1', 'tr2'],
#       dtype='object')

# %%
# Crear el gráfico
plt.figure(figsize=(12, 7))

for variable in variables1:
    plt.plot(data1['k'], data1[variable], marker='o', label=f'Archivo 1 - {variable}')
    
for variable in variables2:
    plt.plot(data2['k'], data2[variable], marker='o', label=f'Archivo 2 - {variable}')
        
# Configuración del gráfico
plt.xscale('log')  # Escala logarítmica en el eje x
plt.xlabel('k results')
plt.ylabel('Time (ms)')
plt.title('Gradual retrieval (DFUDS - backtracking)')
plt.legend()
plt.grid(True)

# Colocar la leyenda al lado del gráfico
plt.legend(bbox_to_anchor=(1.05, .75), loc='upper left', borderaxespad=0.)

# Mostrar el gráfico
plt.tight_layout(rect=[0, 0, 0.85, 1])

# Guardar el gráfico
plt.savefig('plot_type_fun_0.png')

# Mostrar el gráfico
plt.show()

# %%
for type_fun in [0,1]:
    file = f"../ranked/louds/backtracking/results-f{type_fun}.csv"
    print(file)
# Out:
# ../ranked/louds/backtracking/results-f0.csv
# ../ranked/louds/backtracking/results-f1.csv
